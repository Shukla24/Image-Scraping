# %%
import requests
from bs4 import BeautifulSoup
import lxml

# %%
#url="https://www.amazon.in/s?k=laptop&page=1&qid=1604127614&ref=sr_pg_1"
url="https://www.amazon.in/s?k=saree&page=5&qid=1617950080&ref=sr_pg_5"
headers = {
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
    }

# %% [markdown]
# # creat the file for different item like saree,jeans,trouser

# %%
variablename = input("enter the search keyword")
lst=[]
count=1
url=[]
c=0
for i in range(2,6):
    url.append(f"https://www.amazon.in/s?k={variablename}&page={i}&qid=1617950080&ref=sr_pg_{i}")
    res=requests.get(url[c],headers=headers)
    soup = BeautifulSoup(res.text, 'lxml')
    img=soup.select(".rush-component a div img")
    c=c+1
    for j in img:
        print(count,end=" ")
        print(j['src'])
        lst.append(j['src'])

        count=count+1
# Out:
# enter the search keywordtrouser
# 1 https://m.media-amazon.com/images/I/81gnI2QcyML._AC_SX200_SY161_QL70_.jpg
# 2 https://m.media-amazon.com/images/I/71MB3yNQc5L._AC_SX200_SY161_QL70_.jpg
# 3 https://m.media-amazon.com/images/I/91XnkSIYvDL._AC_SX200_SY161_QL70_.jpg
# 4 https://m.media-amazon.com/images/I/71g3wpopNjL._AC_UL320_.jpg
# 5 https://m.media-amazon.com/images/I/71h--R5Zn5L._AC_UL320_.jpg
# 6 https://m.media-amazon.com/images/I/71MW2+0BFQL._AC_UL320_.jpg
# 7 https://m.media-amazon.com/images/I/81zJ1ThxSGL._AC_UL320_.jpg
# 8 https://m.media-amazon.com/images/I/31QYXZdXqtL._AC_UL320_.jpg
# 9 https://m.media-amazon.com/images/I/91ZOIu+Ic8L._AC_UL320_.jpg
# 10 https://m.media-amazon.com/images/I/61oaPYz08nL._AC_UL320_.jpg
# 11 https://m.media-amazon.com/images/I/712zxs-ZWkL._AC_UL320_.jpg
# 12 https://m.media-amazon.com/images/I/71iA2zQdFbL._AC_UL320_.jpg
# 13 https://m.media-amazon.com/images/I/81oiHGQOGPL._AC_UL320_.jpg
# ...

# %%
import requests

img_list=lst
for item_data in img_list:
    print(type(item_data),item_data)
    img=item_data[-26:]
    local_file = open('itemfolder/{0}/{1}'.format(variablename,img),'wb')
    image_url = str(item_data)
    resp = requests.get(image_url, stream=True)
    local_file.write(resp.content)
    local_file.close()
# Out:
# <class 'str'> https://m.media-amazon.com/images/I/81gnI2QcyML._AC_SX200_SY161_QL70_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/71MB3yNQc5L._AC_SX200_SY161_QL70_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/91XnkSIYvDL._AC_SX200_SY161_QL70_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/71g3wpopNjL._AC_UL320_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/71h--R5Zn5L._AC_UL320_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/71MW2+0BFQL._AC_UL320_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/81zJ1ThxSGL._AC_UL320_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/31QYXZdXqtL._AC_UL320_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/91ZOIu+Ic8L._AC_UL320_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/61oaPYz08nL._AC_UL320_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/712zxs-ZWkL._AC_UL320_.jpg
# <class 'str'> https://m.media-amazon.com/images/I/71iA2zQdFbL._AC_UL320_.jpg
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [raw]
# pip3 install --upgrade tensorflow-gpu --user
# installing the tenserflow

# %%
import pathlib
data_dir='C:/Users/Dell/SP ClothDeep Learning/itemfolder'
data_dir = pathlib.Path(data_dir)

# %%
data_dir
# Out:
# WindowsPath('C:/Users/Dell/SP ClothDeep Learning/itemfolder')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 753

# %%
jeans = list(data_dir.glob('jeans/*'))
PIL.Image.open(str(jeans[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=146x320 at 0x240FC368E08>

# %%
PIL.Image.open(str(jeans[3]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x320 at 0x240FC368708>

# %%
trouser = list(data_dir.glob('trouser/*'))
PIL.Image.open(str(trouser[2]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=84x161 at 0x240FC3D7348>

# %%
PIL.Image.open(str(trouser[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=59x120 at 0x240FC3D7688>

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 754 files belonging to 3 classes.
# Using 604 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 754 files belonging to 3 classes.
# Using 150 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['jeans', 'saree', 'trouser']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = 5
model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# rescaling_4 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 22, 22, 64)        0
# ...

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 19/19 [==============================] - 9s 438ms/step - loss: 1.2388 - accuracy: 0.4208 - val_loss: 0.5466 - val_accuracy: 0.6533
# Epoch 2/10
# 19/19 [==============================] - 7s 394ms/step - loss: 0.4115 - accuracy: 0.7879 - val_loss: 0.4052 - val_accuracy: 0.8200
# Epoch 3/10
# 19/19 [==============================] - 7s 375ms/step - loss: 0.2632 - accuracy: 0.9018 - val_loss: 0.5063 - val_accuracy: 0.7867
# Epoch 4/10
# 19/19 [==============================] - 7s 383ms/step - loss: 0.2352 - accuracy: 0.9044 - val_loss: 0.4332 - val_accuracy: 0.8000
# Epoch 5/10
# 19/19 [==============================] - 7s 373ms/step - loss: 0.1897 - accuracy: 0.9145 - val_loss: 0.4058 - val_accuracy: 0.8400
# Epoch 6/10
# 19/19 [==============================] - 7s 364ms/step - loss: 0.1680 - accuracy: 0.9288 - val_loss: 0.4718 - val_accuracy: 0.8267
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# sequential_4 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_5 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 45, 45, 64)        18496
# ...

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 19/19 [==============================] - 9s 452ms/step - loss: 1.1586 - accuracy: 0.4826 - val_loss: 0.4797 - val_accuracy: 0.7200
# Epoch 2/15
# 19/19 [==============================] - 8s 447ms/step - loss: 0.4978 - accuracy: 0.7676 - val_loss: 0.3856 - val_accuracy: 0.7733
# Epoch 3/15
# 19/19 [==============================] - 9s 457ms/step - loss: 0.4154 - accuracy: 0.8135 - val_loss: 0.3911 - val_accuracy: 0.8067
# Epoch 4/15
# 19/19 [==============================] - 8s 442ms/step - loss: 0.4241 - accuracy: 0.7925 - val_loss: 0.4061 - val_accuracy: 0.7933
# Epoch 5/15
# 19/19 [==============================] - 8s 429ms/step - loss: 0.3654 - accuracy: 0.8392 - val_loss: 0.3649 - val_accuracy: 0.8467
# Epoch 6/15
# 19/19 [==============================] - 8s 435ms/step - loss: 0.3681 - accuracy: 0.8389 - val_loss: 0.3793 - val_accuracy: 0.8400
# Epoch 7/15
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
img = keras.preprocessing.image.load_img(path="sareedata.jpg", target_size=(img_height, img_width))

img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score)))
# Out:
# This image most likely belongs to saree with a 99.79 percent confidence.
